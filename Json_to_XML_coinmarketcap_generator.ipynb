# %% [markdown]
# <a href="https://colab.research.google.com/github/sgardziewicz/JSON-to-XML-generator-for-Coinmarketcap/blob/master/Json_to_XML_coinmarketcap_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data_full = pd.read_json("https://api.coinmarketcap.com/v1/ticker/")

# %%
data = data_full[['id','name','symbol','price_usd','market_cap_usd','percent_change_1h','percent_change_24h','percent_change_7d']]

# %%
def func(row):
    xml = ['<coin>']
    for field in row.index:
        if(field=='percent_change_1h'):
            xml.append('   <percent_change>')
        if(field.startswith('percent')):
            xml.append('      <{0}>{1}</{0}>'.format(field, row[field]))
        else:
            xml.append('   <{0}>{1}</{0}>'.format(field, row[field]))
        if(field=='percent_change_7d'):
            xml.append('   </percent_change>')
        
    xml.append('</coin>')
    return '\n'.join(xml)

# %%
xml_declaration = """<?xml version="1.0" encoding="UTF-8" standalone="no" ?>""" + '\n'

xml = xml_declaration + '\n'.join(data.apply(func, axis=1))

# %%
print(xml)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no" ?>
# <coin>
#    <id>bitcoin</id>
#    <name>Bitcoin</name>
#    <symbol>BTC</symbol>
#    <price_usd>7223.13005773</price_usd>
#    <market_cap_usd>130708136320</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.1</percent_change_1h>
#       <percent_change_24h>-1.07</percent_change_24h>
#       <percent_change_7d>-2.39</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ethereum</id>
#    <name>Ethereum</name>
#    <symbol>ETH</symbol>
#    <price_usd>143.699484571</price_usd>
#    <market_cap_usd>15645796644</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.78</percent_change_1h>
#       <percent_change_24h>-1.82</percent_change_24h>
#       <percent_change_7d>-3.38</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>xrp</id>
#    <name>XRP</name>
#    <symbol>XRP</symbol>
#    <price_usd>0.2226503568</price_usd>
#    <market_cap_usd>9637567849</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.71</percent_change_1h>
#       <percent_change_24h>0.14</percent_change_24h>
#       <percent_change_7d>1.89</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>tether</id>
#    <name>Tether</name>
#    <symbol>USDT</symbol>
#    <price_usd>1.0197659238</price_usd>
#    <market_cap_usd>4189243750</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.92</percent_change_1h>
#       <percent_change_24h>1.57</percent_change_24h>
#       <percent_change_7d>1.59</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-cash</id>
#    <name>Bitcoin Cash</name>
#    <symbol>BCH</symbol>
#    <price_usd>206.811894549</price_usd>
#    <market_cap_usd>3755944424</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.94</percent_change_1h>
#       <percent_change_24h>-0.05</percent_change_24h>
#       <percent_change_7d>-2.67</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>litecoin</id>
#    <name>Litecoin</name>
#    <symbol>LTC</symbol>
#    <price_usd>44.0576639977</price_usd>
#    <market_cap_usd>2811682861</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.38</percent_change_1h>
#       <percent_change_24h>-0.78</percent_change_24h>
#       <percent_change_7d>-3.76</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>eos</id>
#    <name>EOS</name>
#    <symbol>EOS</symbol>
#    <price_usd>2.5779204766</price_usd>
#    <market_cap_usd>2433300382</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.83</percent_change_1h>
#       <percent_change_24h>-2.13</percent_change_24h>
#       <percent_change_7d>-3.88</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>binance-coin</id>
#    <name>Binance Coin</name>
#    <symbol>BNB</symbol>
#    <price_usd>14.7824193486</price_usd>
#    <market_cap_usd>2299208916</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.69</percent_change_1h>
#       <percent_change_24h>-0.79</percent_change_24h>
#       <percent_change_7d>-4.43</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-sv</id>
#    <name>Bitcoin SV</name>
#    <symbol>BSV</symbol>
#    <price_usd>95.0420054196</price_usd>
#    <market_cap_usd>1717258396</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.16</percent_change_1h>
#       <percent_change_24h>-0.65</percent_change_24h>
#       <percent_change_7d>-3.23</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>stellar</id>
#    <name>Stellar</name>
#    <symbol>XLM</symbol>
#    <price_usd>0.0537624429</price_usd>
#    <market_cap_usd>1078193941</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.79</percent_change_1h>
#       <percent_change_24h>-0.48</percent_change_24h>
#       <percent_change_7d>-3.72</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>tezos</id>
#    <name>Tezos</name>
#    <symbol>XTZ</symbol>
#    <price_usd>1.5070697169</price_usd>
#    <market_cap_usd>995229072</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.91</percent_change_1h>
#       <percent_change_24h>4.55</percent_change_24h>
#       <percent_change_7d>17.24</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>cardano</id>
#    <name>Cardano</name>
#    <symbol>ADA</symbol>
#    <price_usd>0.0365331568</price_usd>
#    <market_cap_usd>947197734</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.37</percent_change_1h>
#       <percent_change_24h>-0.06</percent_change_24h>
#       <percent_change_7d>-3.0</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>tron</id>
#    <name>TRON</name>
#    <symbol>TRX</symbol>
#    <price_usd>0.0141028262</price_usd>
#    <market_cap_usd>940405675</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.49</percent_change_1h>
#       <percent_change_24h>-1.06</percent_change_24h>
#       <percent_change_7d>-4.07</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>monero</id>
#    <name>Monero</name>
#    <symbol>XMR</symbol>
#    <price_usd>53.0179975616</price_usd>
#    <market_cap_usd>919836827</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.3</percent_change_1h>
#       <percent_change_24h>-0.62</percent_change_24h>
#       <percent_change_7d>-2.39</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>unus-sed-leo</id>
#    <name>UNUS SED LEO</name>
#    <symbol>LEO</symbol>
#    <price_usd>0.9014914579</price_usd>
#    <market_cap_usd>901039714</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.25</percent_change_1h>
#       <percent_change_24h>-0.25</percent_change_24h>
#       <percent_change_7d>-1.95</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>chainlink</id>
#    <name>Chainlink</name>
#    <symbol>LINK</symbol>
#    <price_usd>2.1913634604</price_usd>
#    <market_cap_usd>766977211</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.25</percent_change_1h>
#       <percent_change_24h>0.12</percent_change_24h>
#       <percent_change_7d>5.06</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>cosmos</id>
#    <name>Cosmos</name>
#    <symbol>ATOM</symbol>
#    <price_usd>3.6524618666</price_usd>
#    <market_cap_usd>696482253</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.72</percent_change_1h>
#       <percent_change_24h>1.85</percent_change_24h>
#       <percent_change_7d>0.18</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>huobi-token</id>
#    <name>Huobi Token</name>
#    <symbol>HT</symbol>
#    <price_usd>2.7167500526</price_usd>
#    <market_cap_usd>655508447</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.6</percent_change_1h>
#       <percent_change_24h>0.66</percent_change_24h>
#       <percent_change_7d>-5.35</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>999-coin</id>
#    <name>999</name>
#    <symbol>999</symbol>
#    <price_usd>2.8752240185</price_usd>
#    <market_cap_usd>624214452</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.82</percent_change_1h>
#       <percent_change_24h>24.78</percent_change_24h>
#       <percent_change_7d>391.61</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>neo</id>
#    <name>NEO</name>
#    <symbol>NEO</symbol>
#    <price_usd>8.5258580763</price_usd>
#    <market_cap_usd>601404062</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.86</percent_change_1h>
#       <percent_change_24h>-0.8</percent_change_24h>
#       <percent_change_7d>-4.29</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>iota</id>
#    <name>IOTA</name>
#    <symbol>MIOTA</symbol>
#    <price_usd>0.1976686229</price_usd>
#    <market_cap_usd>549425923</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.43</percent_change_1h>
#       <percent_change_24h>-0.24</percent_change_24h>
#       <percent_change_7d>-2.3</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>maker</id>
#    <name>Maker</name>
#    <symbol>MKR</symbol>
#    <price_usd>491.610213347</price_usd>
#    <market_cap_usd>491610213</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.2</percent_change_1h>
#       <percent_change_24h>-2.54</percent_change_24h>
#       <percent_change_7d>-10.52</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>usd-coin</id>
#    <name>USD Coin</name>
#    <symbol>USDC</symbol>
#    <price_usd>1.0066394588</price_usd>
#    <market_cap_usd>481131654</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.42</percent_change_1h>
#       <percent_change_24h>0.15</percent_change_24h>
#       <percent_change_7d>0.29</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dash</id>
#    <name>Dash</name>
#    <symbol>DASH</symbol>
#    <price_usd>49.9045890958</price_usd>
#    <market_cap_usd>459361284</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.37</percent_change_1h>
#       <percent_change_24h>-0.95</percent_change_24h>
#       <percent_change_7d>-2.77</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>mindol</id>
#    <name>MINDOL</name>
#    <symbol>MIN</symbol>
#    <price_usd>2.8982332098</price_usd>
#    <market_cap_usd>449082344</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-4.06</percent_change_1h>
#       <percent_change_24h>19.88</percent_change_24h>
#       <percent_change_7d>79.08</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ethereum-classic</id>
#    <name>Ethereum Classic</name>
#    <symbol>ETC</symbol>
#    <price_usd>3.7922562529</price_usd>
#    <market_cap_usd>439095329</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.09</percent_change_1h>
#       <percent_change_24h>0.23</percent_change_24h>
#       <percent_change_7d>-0.74</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ontology</id>
#    <name>Ontology</name>
#    <symbol>ONT</symbol>
#    <price_usd>0.5926781569</price_usd>
#    <market_cap_usd>377744117</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.73</percent_change_1h>
#       <percent_change_24h>0.02</percent_change_24h>
#       <percent_change_7d>-2.8</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>crypto-com-coin</id>
#    <name>Crypto.com Coin</name>
#    <symbol>CRO</symbol>
#    <price_usd>0.029000817</price_usd>
#    <market_cap_usd>355504992</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.92</percent_change_1h>
#       <percent_change_24h>-0.91</percent_change_24h>
#       <percent_change_7d>9.68</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>vechain</id>
#    <name>VeChain</name>
#    <symbol>VET</symbol>
#    <price_usd>0.0061720545</price_usd>
#    <market_cap_usd>342269647</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.91</percent_change_1h>
#       <percent_change_24h>0.14</percent_change_24h>
#       <percent_change_7d>-15.38</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>nem</id>
#    <name>NEM</name>
#    <symbol>XEM</symbol>
#    <price_usd>0.0358945729</price_usd>
#    <market_cap_usd>323051156</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.03</percent_change_1h>
#       <percent_change_24h>2.38</percent_change_24h>
#       <percent_change_7d>-0.46</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>hedgetrade</id>
#    <name>HedgeTrade</name>
#    <symbol>HEDG</symbol>
#    <price_usd>1.0894039444</price_usd>
#    <market_cap_usd>313873460</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.05</percent_change_1h>
#       <percent_change_24h>1.14</percent_change_24h>
#       <percent_change_7d>50.46</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ino-coin</id>
#    <name>INO COIN</name>
#    <symbol>INO</symbol>
#    <price_usd>1.5845363192</price_usd>
#    <market_cap_usd>285221576</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.45</percent_change_1h>
#       <percent_change_24h>-1.06</percent_change_24h>
#       <percent_change_7d>-1.9</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dogecoin</id>
#    <name>Dogecoin</name>
#    <symbol>DOGE</symbol>
#    <price_usd>0.0021905913</price_usd>
#    <market_cap_usd>268181472</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.82</percent_change_1h>
#       <percent_change_24h>-0.54</percent_change_24h>
#       <percent_change_7d>-0.95</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>basic-attention-token</id>
#    <name>Basic Attention Token</name>
#    <symbol>BAT</symbol>
#    <price_usd>0.1770215877</price_usd>
#    <market_cap_usd>249769351</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.01</percent_change_1h>
#       <percent_change_24h>0.63</percent_change_24h>
#       <percent_change_7d>-5.55</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>zcash</id>
#    <name>Zcash</name>
#    <symbol>ZEC</symbol>
#    <price_usd>30.7780849925</price_usd>
#    <market_cap_usd>247550638</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.04</percent_change_1h>
#       <percent_change_24h>2.96</percent_change_24h>
#       <percent_change_7d>12.08</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>paxos-standard</id>
#    <name>Paxos Standard</name>
#    <symbol>PAX</symbol>
#    <price_usd>1.0071031548</price_usd>
#    <market_cap_usd>236098384</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.39</percent_change_1h>
#       <percent_change_24h>0.12</percent_change_24h>
#       <percent_change_7d>0.28</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>decred</id>
#    <name>Decred</name>
#    <symbol>DCR</symbol>
#    <price_usd>19.8737399296</price_usd>
#    <market_cap_usd>214374672</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.65</percent_change_1h>
#       <percent_change_24h>1.49</percent_change_24h>
#       <percent_change_7d>3.44</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>insight-chain</id>
#    <name>Insight Chain</name>
#    <symbol>INB</symbol>
#    <price_usd>0.5294964699</price_usd>
#    <market_cap_usd>185272239</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.84</percent_change_1h>
#       <percent_change_24h>0.85</percent_change_24h>
#       <percent_change_7d>-2.87</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>synthetix-network-token</id>
#    <name>Synthetix Network Token</name>
#    <symbol>SNX</symbol>
#    <price_usd>1.2284682273</price_usd>
#    <market_cap_usd>184006139</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.78</percent_change_1h>
#       <percent_change_24h>1.82</percent_change_24h>
#       <percent_change_7d>-7.77</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>prizm</id>
#    <name>PRIZM</name>
#    <symbol>PZM</symbol>
#    <price_usd>0.3562997405</price_usd>
#    <market_cap_usd>177042674</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>2.16</percent_change_1h>
#       <percent_change_24h>24.73</percent_change_24h>
#       <percent_change_7d>-7.35</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>qtum</id>
#    <name>Qtum</name>
#    <symbol>QTUM</symbol>
#    <price_usd>1.7212664464</price_usd>
#    <market_cap_usd>165634276</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.72</percent_change_1h>
#       <percent_change_24h>-0.39</percent_change_24h>
#       <percent_change_7d>-1.06</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>trueusd</id>
#    <name>TrueUSD</name>
#    <symbol>TUSD</symbol>
#    <price_usd>1.0060674171</price_usd>
#    <market_cap_usd>161406121</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.36</percent_change_1h>
#       <percent_change_24h>0.28</percent_change_24h>
#       <percent_change_7d>0.6</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>centrality</id>
#    <name>Centrality</name>
#    <symbol>CENNZ</symbol>
#    <price_usd>0.126529406</price_usd>
#    <market_cap_usd>135315885</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-3.45</percent_change_1h>
#       <percent_change_24h>-3.63</percent_change_24h>
#       <percent_change_7d>-5.86</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>0x</id>
#    <name>0x</name>
#    <symbol>ZRX</symbol>
#    <price_usd>0.2199179625</price_usd>
#    <market_cap_usd>132923248</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.0</percent_change_1h>
#       <percent_change_24h>-1.49</percent_change_24h>
#       <percent_change_7d>-8.21</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>algorand</id>
#    <name>Algorand</name>
#    <symbol>ALGO</symbol>
#    <price_usd>0.2847011552</price_usd>
#    <market_cap_usd>131856794</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.28</percent_change_1h>
#       <percent_change_24h>4.23</percent_change_24h>
#       <percent_change_7d>3.27</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ravencoin</id>
#    <name>Ravencoin</name>
#    <symbol>RVN</symbol>
#    <price_usd>0.0247834567</price_usd>
#    <market_cap_usd>125055959</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-4.78</percent_change_1h>
#       <percent_change_24h>2.97</percent_change_24h>
#       <percent_change_7d>-9.3</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>thorecoin</id>
#    <name>ThoreCoin</name>
#    <symbol>THR</symbol>
#    <price_usd>1369.32960062</price_usd>
#    <market_cap_usd>118701735</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.19</percent_change_1h>
#       <percent_change_24h>-1.08</percent_change_24h>
#       <percent_change_7d>-2.46</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>thorenext</id>
#    <name>ThoreNext</name>
#    <symbol>THX</symbol>
#    <price_usd>5.4246241163</price_usd>
#    <market_cap_usd>117455339</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.22</percent_change_1h>
#       <percent_change_24h>-3.2</percent_change_24h>
#       <percent_change_7d>-12.7</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ftx-token</id>
#    <name>FTX Token</name>
#    <symbol>FTT</symbol>
#    <price_usd>1.7257442608</price_usd>
#    <market_cap_usd>116026861</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.91</percent_change_1h>
#       <percent_change_24h>-3.04</percent_change_24h>
#       <percent_change_7d>-0.87</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>augur</id>
#    <name>Augur</name>
#    <symbol>REP</symbol>
#    <price_usd>10.2136464695</price_usd>
#    <market_cap_usd>112350111</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.79</percent_change_1h>
#       <percent_change_24h>1.59</percent_change_24h>
#       <percent_change_7d>0.47</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>holo</id>
#    <name>Holo</name>
#    <symbol>HOT</symbol>
#    <price_usd>0.0006748277</price_usd>
#    <market_cap_usd>108997599</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.76</percent_change_1h>
#       <percent_change_24h>-0.52</percent_change_24h>
#       <percent_change_7d>-12.88</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>nano</id>
#    <name>Nano</name>
#    <symbol>NANO</symbol>
#    <price_usd>0.804032188</price_usd>
#    <market_cap_usd>107135920</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.49</percent_change_1h>
#       <percent_change_24h>0.82</percent_change_24h>
#       <percent_change_7d>-2.05</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>karatgold-coin</id>
#    <name>Karatgold Coin</name>
#    <symbol>KBC</symbol>
#    <price_usd>0.0283990174</price_usd>
#    <market_cap_usd>106569066</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.98</percent_change_1h>
#       <percent_change_24h>0.63</percent_change_24h>
#       <percent_change_7d>5.29</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>cryptonex</id>
#    <name>Cryptonex</name>
#    <symbol>CNX</symbol>
#    <price_usd>1.9004148901</price_usd>
#    <market_cap_usd>105827129</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.92</percent_change_1h>
#       <percent_change_24h>-0.2</percent_change_24h>
#       <percent_change_7d>-1.27</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>seele</id>
#    <name>Seele</name>
#    <symbol>SEELE</symbol>
#    <price_usd>0.1511997978</price_usd>
#    <market_cap_usd>105773664</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.16</percent_change_1h>
#       <percent_change_24h>0.71</percent_change_24h>
#       <percent_change_7d>-6.68</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>educare</id>
#    <name>EDUCare</name>
#    <symbol>EKT</symbol>
#    <price_usd>0.1040297917</price_usd>
#    <market_cap_usd>104029792</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.18</percent_change_1h>
#       <percent_change_24h>3.06</percent_change_24h>
#       <percent_change_7d>32.25</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>omisego</id>
#    <name>OmiseGO</name>
#    <symbol>OMG</symbol>
#    <price_usd>0.7245715693</price_usd>
#    <market_cap_usd>101617828</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.1</percent_change_1h>
#       <percent_change_24h>0.33</percent_change_24h>
#       <percent_change_7d>-2.11</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-gold</id>
#    <name>Bitcoin Gold</name>
#    <symbol>BTG</symbol>
#    <price_usd>5.7144838448</price_usd>
#    <market_cap_usd>100083033</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.53</percent_change_1h>
#       <percent_change_24h>-0.57</percent_change_24h>
#       <percent_change_7d>-4.57</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>mixin</id>
#    <name>Mixin</name>
#    <symbol>XIN</symbol>
#    <price_usd>213.214310533</price_usd>
#    <market_cap_usd>99448210</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.54</percent_change_1h>
#       <percent_change_24h>-0.63</percent_change_24h>
#       <percent_change_7d>-1.65</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>abbc-coin</id>
#    <name>ABBC Coin</name>
#    <symbol>ABBC</symbol>
#    <price_usd>0.1628827848</price_usd>
#    <market_cap_usd>90664896</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.87</percent_change_1h>
#       <percent_change_24h>-0.68</percent_change_24h>
#       <percent_change_7d>-4.42</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>zb-token</id>
#    <name>ZB Token</name>
#    <symbol>ZB</symbol>
#    <price_usd>0.1894775888</price_usd>
#    <market_cap_usd>87782847</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.67</percent_change_1h>
#       <percent_change_24h>-1.32</percent_change_24h>
#       <percent_change_7d>-2.82</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>v-systems</id>
#    <name>V Systems</name>
#    <symbol>VSYS</symbol>
#    <price_usd>0.0452222371</price_usd>
#    <market_cap_usd>84670980</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.74</percent_change_1h>
#       <percent_change_24h>-5.1</percent_change_24h>
#       <percent_change_7d>-13.67</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>digibyte</id>
#    <name>DigiByte</name>
#    <symbol>DGB</symbol>
#    <price_usd>0.0064806938</price_usd>
#    <market_cap_usd>81578563</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.95</percent_change_1h>
#       <percent_change_24h>0.3</percent_change_24h>
#       <percent_change_7d>-3.69</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>lisk</id>
#    <name>Lisk</name>
#    <symbol>LSK</symbol>
#    <price_usd>0.6540065586</price_usd>
#    <market_cap_usd>79762650</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.17</percent_change_1h>
#       <percent_change_24h>-0.05</percent_change_24h>
#       <percent_change_7d>-2.49</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>kucoin-shares</id>
#    <name>KuCoin Shares</name>
#    <symbol>KCS</symbol>
#    <price_usd>0.946275194</price_usd>
#    <market_cap_usd>77938585</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.63</percent_change_1h>
#       <percent_change_24h>0.61</percent_change_24h>
#       <percent_change_7d>-2.01</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dimension-chain</id>
#    <name>Dimension Chain</name>
#    <symbol>EON</symbol>
#    <price_usd>0.3154684209</price_usd>
#    <market_cap_usd>77221483</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.08</percent_change_1h>
#       <percent_change_24h>-2.56</percent_change_24h>
#       <percent_change_7d>-10.6</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>luna</id>
#    <name>LUNA</name>
#    <symbol>LUNA</symbol>
#    <price_usd>0.2601345591</price_usd>
#    <market_cap_usd>74857831</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.14</percent_change_1h>
#       <percent_change_24h>1.6</percent_change_24h>
#       <percent_change_7d>4.04</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bytom</id>
#    <name>Bytom</name>
#    <symbol>BTM</symbol>
#    <price_usd>0.0741509761</price_usd>
#    <market_cap_usd>74336300</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.12</percent_change_1h>
#       <percent_change_24h>-1.18</percent_change_24h>
#       <percent_change_7d>-6.35</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>verge</id>
#    <name>Verge</name>
#    <symbol>XVG</symbol>
#    <price_usd>0.0043545985</price_usd>
#    <market_cap_usd>70110665</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.29</percent_change_1h>
#       <percent_change_24h>5.91</percent_change_24h>
#       <percent_change_7d>10.32</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>komodo</id>
#    <name>Komodo</name>
#    <symbol>KMD</symbol>
#    <price_usd>0.5931409867</price_usd>
#    <market_cap_usd>69571559</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.03</percent_change_1h>
#       <percent_change_24h>-0.02</percent_change_24h>
#       <percent_change_7d>-13.07</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-diamond</id>
#    <name>Bitcoin Diamond</name>
#    <symbol>BCD</symbol>
#    <price_usd>0.3678633865</price_usd>
#    <market_cap_usd>68603909</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.67</percent_change_1h>
#       <percent_change_24h>-0.17</percent_change_24h>
#       <percent_change_7d>-0.23</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>gaps</id>
#    <name>GAPS</name>
#    <symbol>GAP</symbol>
#    <price_usd>6.8297636152</price_usd>
#    <market_cap_usd>68297636</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.67</percent_change_1h>
#       <percent_change_24h>-2.25</percent_change_24h>
#       <percent_change_7d>-1.7</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>molecular-future</id>
#    <name>Molecular Future</name>
#    <symbol>MOF</symbol>
#    <price_usd>1.5365455407</price_usd>
#    <market_cap_usd>67381940</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.86</percent_change_1h>
#       <percent_change_24h>-3.44</percent_change_24h>
#       <percent_change_7d>5.86</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>theta</id>
#    <name>THETA</name>
#    <symbol>THETA</symbol>
#    <price_usd>0.0772970896</price_usd>
#    <market_cap_usd>67287324</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-3.11</percent_change_1h>
#       <percent_change_24h>1.88</percent_change_24h>
#       <percent_change_7d>3.87</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>1irstcoin</id>
#    <name>1irstcoin</name>
#    <symbol>FST</symbol>
#    <price_usd>1.8044238317</price_usd>
#    <market_cap_usd>66954097</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.96</percent_change_1h>
#       <percent_change_24h>-1.99</percent_change_24h>
#       <percent_change_7d>-6.35</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>swipe</id>
#    <name>Swipe</name>
#    <symbol>SXP</symbol>
#    <price_usd>1.0937240817</price_usd>
#    <market_cap_usd>66865818</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.16</percent_change_1h>
#       <percent_change_24h>-1.3</percent_change_24h>
#       <percent_change_7d>-4.76</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>beldex</id>
#    <name>Beldex</name>
#    <symbol>BDX</symbol>
#    <price_usd>0.0677610864</price_usd>
#    <market_cap_usd>66420948</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.25</percent_change_1h>
#       <percent_change_24h>-2.47</percent_change_24h>
#       <percent_change_7d>-1.71</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>crypto-com</id>
#    <name>MCO</name>
#    <symbol>MCO</symbol>
#    <price_usd>4.1419430587</price_usd>
#    <market_cap_usd>65417149</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.05</percent_change_1h>
#       <percent_change_24h>-0.01</percent_change_24h>
#       <percent_change_7d>3.34</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>icon</id>
#    <name>ICON</name>
#    <symbol>ICX</symbol>
#    <price_usd>0.1265757865</price_usd>
#    <market_cap_usd>64442784</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.56</percent_change_1h>
#       <percent_change_24h>0.15</percent_change_24h>
#       <percent_change_7d>-4.05</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>waves</id>
#    <name>Waves</name>
#    <symbol>WAVES</symbol>
#    <price_usd>0.6312124775</price_usd>
#    <market_cap_usd>63479933</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.79</percent_change_1h>
#       <percent_change_24h>18.21</percent_change_24h>
#       <percent_change_7d>8.36</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>iostoken</id>
#    <name>IOST</name>
#    <symbol>IOST</symbol>
#    <price_usd>0.0052405962</price_usd>
#    <market_cap_usd>62960342</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.49</percent_change_1h>
#       <percent_change_24h>0.14</percent_change_24h>
#       <percent_change_7d>-9.6</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bittorrent</id>
#    <name>BitTorrent</name>
#    <symbol>BTT</symbol>
#    <price_usd>0.0002893279</price_usd>
#    <market_cap_usd>61371221</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.96</percent_change_1h>
#       <percent_change_24h>-0.33</percent_change_24h>
#       <percent_change_7d>-6.03</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>enjin-coin</id>
#    <name>Enjin Coin</name>
#    <symbol>ENJ</symbol>
#    <price_usd>0.0775627932</price_usd>
#    <market_cap_usd>60884050</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-4.32</percent_change_1h>
#       <percent_change_24h>9.13</percent_change_24h>
#       <percent_change_7d>14.64</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>siacoin</id>
#    <name>Siacoin</name>
#    <symbol>SC</symbol>
#    <price_usd>0.0014257967</price_usd>
#    <market_cap_usd>59622611</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.42</percent_change_1h>
#       <percent_change_24h>-1.58</percent_change_24h>
#       <percent_change_7d>-6.61</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>monacoin</id>
#    <name>MonaCoin</name>
#    <symbol>MONA</symbol>
#    <price_usd>0.8806002765</price_usd>
#    <market_cap_usd>57881570</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.87</percent_change_1h>
#       <percent_change_24h>-0.71</percent_change_24h>
#       <percent_change_7d>-1.67</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>clipper-coin</id>
#    <name>Clipper Coin</name>
#    <symbol>CCC</symbol>
#    <price_usd>0.0192562772</price_usd>
#    <market_cap_usd>56676427</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.85</percent_change_1h>
#       <percent_change_24h>-15.92</percent_change_24h>
#       <percent_change_7d>-25.57</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dxchain-token</id>
#    <name>DxChain Token</name>
#    <symbol>DX</symbol>
#    <price_usd>0.0011302427</price_usd>
#    <market_cap_usd>56512136</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.29</percent_change_1h>
#       <percent_change_24h>-1.08</percent_change_24h>
#       <percent_change_7d>-1.18</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bytecoin-bcn</id>
#    <name>Bytecoin</name>
#    <symbol>BCN</symbol>
#    <price_usd>0.0003040342</price_usd>
#    <market_cap_usd>55962609</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-7.15</percent_change_1h>
#       <percent_change_24h>-5.45</percent_change_24h>
#       <percent_change_7d>-3.31</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>single-collateral-dai</id>
#    <name>Single Collateral DAI </name>
#    <symbol>SAI</symbol>
#    <price_usd>1.0072596441</price_usd>
#    <market_cap_usd>54720952</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.28</percent_change_1h>
#       <percent_change_24h>0.24</percent_change_24h>
#       <percent_change_7d>0.28</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>zilliqa</id>
#    <name>Zilliqa</name>
#    <symbol>ZIL</symbol>
#    <price_usd>0.0055285376</price_usd>
#    <market_cap_usd>53854865</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-3.29</percent_change_1h>
#       <percent_change_24h>-0.42</percent_change_24h>
#       <percent_change_7d>-2.14</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitshares</id>
#    <name>BitShares</name>
#    <symbol>BTS</symbol>
#    <price_usd>0.0192901733</price_usd>
#    <market_cap_usd>53033702</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.72</percent_change_1h>
#       <percent_change_24h>-0.73</percent_change_24h>
#       <percent_change_7d>-5.47</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>nexo</id>
#    <name>Nexo</name>
#    <symbol>NEXO</symbol>
#    <price_usd>0.0941620287</price_usd>
#    <market_cap_usd>52730737</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.74</percent_change_1h>
#       <percent_change_24h>-0.95</percent_change_24h>
#       <percent_change_7d>-0.98</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>hypercash</id>
#    <name>HyperCash</name>
#    <symbol>HC</symbol>
#    <price_usd>1.1681989982</price_usd>
#    <market_cap_usd>51928129</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.94</percent_change_1h>
#       <percent_change_24h>-0.99</percent_change_24h>
#       <percent_change_7d>-4.73</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>quant</id>
#    <name>Quant</name>
#    <symbol>QNT</symbol>
#    <price_usd>4.2918967348</price_usd>
#    <market_cap_usd>51814945</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.6</percent_change_1h>
#       <percent_change_24h>-7.7</percent_change_24h>
#       <percent_change_7d>-15.77</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>okb</id>
#    <name>OKB</name>
#    <symbol>OKB</symbol>
#    <price_usd>2.545634284</price_usd>
#    <market_cap_usd>50912686</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.18</percent_change_1h>
#       <percent_change_24h>-3.4</percent_change_24h>
#       <percent_change_7d>-3.13</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>maidsafecoin</id>
#    <name>MaidSafeCoin</name>
#    <symbol>MAID</symbol>
#    <price_usd>0.1116201402</price_usd>
#    <market_cap_usd>50513964</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.08</percent_change_1h>
#       <percent_change_24h>-0.05</percent_change_24h>
#       <percent_change_7d>-7.0</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitbook-gambling</id>
#    <name>Bitbook Gambling</name>
#    <symbol>BXK</symbol>
#    <price_usd>0.1336703321</price_usd>
#    <market_cap_usd>49242478</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>1.04</percent_change_1h>
#       <percent_change_24h>0.54</percent_change_24h>
#       <percent_change_7d>-1.57</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>jewel</id>
#    <name>Jewel</name>
#    <symbol>JWL</symbol>
#    <price_usd>0.894710547</price_usd>
#    <market_cap_usd>48949645</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.12</percent_change_1h>
#       <percent_change_24h>17.83</percent_change_24h>
#       <percent_change_7d>20.22</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>horizen</id>
#    <name>Horizen</name>
#    <symbol>ZEN</symbol>
#    <price_usd>6.1045818616</price_usd>
#    <market_cap_usd>48562254</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.1</percent_change_1h>
#       <percent_change_24h>-1.21</percent_change_24h>
#       <percent_change_7d>18.14</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>minebee</id>
#    <name>MineBee</name>
#    <symbol>MB</symbol>
#    <price_usd>0.0261805049</price_usd>
#    <market_cap_usd>47913399</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.11</percent_change_1h>
#       <percent_change_24h>-1.4</percent_change_24h>
#       <percent_change_7d>-3.06</percent_change_7d>
#    </percent_change>
# </coin>
