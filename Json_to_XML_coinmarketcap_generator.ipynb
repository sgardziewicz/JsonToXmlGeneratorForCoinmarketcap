# %%
import pandas as pd
data_full = pd.read_json("https://api.coinmarketcap.com/v1/ticker/")

# %%
data = data_full[['id','name','symbol','price_usd','market_cap_usd','percent_change_1h','percent_change_24h','percent_change_7d']]

# %%
def func(row):
    xml = ['<coin>']
    for field in row.index:
        if(field=='percent_change_1h'):
            xml.append('   <percent_change>')
        if(field.startswith('percent')):
            xml.append('      <{0}>{1}</{0}>'.format(field, row[field]))
        else:
            xml.append('   <{0}>{1}</{0}>'.format(field, row[field]))
        if(field=='percent_change_7d'):
            xml.append('   </percent_change>')
        
    xml.append('</coin>')
    return '\n'.join(xml)

# %%
xml_declaration = """<?xml version="1.0" encoding="UTF-8" standalone="no" ?>""" + '\n'
tag ="<crypto>" + '\n'
xml = xml_declaration + tag + '\n'.join(data.apply(func, axis=1)) + "</crypto>"

# %%
print(xml)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no" ?>
# <crypto>
# <coin>
#    <id>bitcoin</id>
#    <name>Bitcoin</name>
#    <symbol>BTC</symbol>
#    <price_usd>7238.92521782</price_usd>
#    <market_cap_usd>130994229824</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.34</percent_change_1h>
#       <percent_change_24h>-0.75</percent_change_24h>
#       <percent_change_7d>-2.18</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ethereum</id>
#    <name>Ethereum</name>
#    <symbol>ETH</symbol>
#    <price_usd>143.826321916</price_usd>
#    <market_cap_usd>15659628808</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.64</percent_change_1h>
#       <percent_change_24h>-1.65</percent_change_24h>
#       <percent_change_7d>-3.29</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>xrp</id>
#    <name>XRP</name>
#    <symbol>XRP</symbol>
#    <price_usd>0.2233833886</price_usd>
#    <market_cap_usd>9669297615</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.14</percent_change_1h>
#       <percent_change_24h>0.5</percent_change_24h>
#       <percent_change_7d>2.2</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>tether</id>
#    <name>Tether</name>
#    <symbol>USDT</symbol>
#    <price_usd>1.0174572956</price_usd>
#    <market_cap_usd>4179759803</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.09</percent_change_1h>
#       <percent_change_24h>1.3</percent_change_24h>
#       <percent_change_7d>1.37</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-cash</id>
#    <name>Bitcoin Cash</name>
#    <symbol>BCH</symbol>
#    <price_usd>207.046319908</price_usd>
#    <market_cap_usd>3760209625</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.14</percent_change_1h>
#       <percent_change_24h>0.13</percent_change_24h>
#       <percent_change_7d>-2.57</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>litecoin</id>
#    <name>Litecoin</name>
#    <symbol>LTC</symbol>
#    <price_usd>44.0466473567</price_usd>
#    <market_cap_usd>2810982551</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.46</percent_change_1h>
#       <percent_change_24h>-0.74</percent_change_24h>
#       <percent_change_7d>-3.79</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>eos</id>
#    <name>EOS</name>
#    <symbol>EOS</symbol>
#    <price_usd>2.5826128494</price_usd>
#    <market_cap_usd>2437729515</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.31</percent_change_1h>
#       <percent_change_24h>-1.82</percent_change_24h>
#       <percent_change_7d>-3.73</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>binance-coin</id>
#    <name>Binance Coin</name>
#    <symbol>BNB</symbol>
#    <price_usd>14.8392910032</price_usd>
#    <market_cap_usd>2308054546</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.21</percent_change_1h>
#       <percent_change_24h>-0.17</percent_change_24h>
#       <percent_change_7d>-4.05</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-sv</id>
#    <name>Bitcoin SV</name>
#    <symbol>BSV</symbol>
#    <price_usd>95.0890401114</price_usd>
#    <market_cap_usd>1718108239</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.53</percent_change_1h>
#       <percent_change_24h>-0.52</percent_change_24h>
#       <percent_change_7d>-3.04</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>stellar</id>
#    <name>Stellar</name>
#    <symbol>XLM</symbol>
#    <price_usd>0.0537744445</price_usd>
#    <market_cap_usd>1078434630</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.17</percent_change_1h>
#       <percent_change_24h>-0.33</percent_change_24h>
#       <percent_change_7d>-3.69</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>tezos</id>
#    <name>Tezos</name>
#    <symbol>XTZ</symbol>
#    <price_usd>1.5233651608</price_usd>
#    <market_cap_usd>1005990154</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.65</percent_change_1h>
#       <percent_change_24h>6.08</percent_change_24h>
#       <percent_change_7d>18.53</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>cardano</id>
#    <name>Cardano</name>
#    <symbol>ADA</symbol>
#    <price_usd>0.0367061578</price_usd>
#    <market_cap_usd>951683143</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.05</percent_change_1h>
#       <percent_change_24h>0.54</percent_change_24h>
#       <percent_change_7d>-2.59</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>tron</id>
#    <name>TRON</name>
#    <symbol>TRX</symbol>
#    <price_usd>0.0141404275</price_usd>
#    <market_cap_usd>942913009</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.43</percent_change_1h>
#       <percent_change_24h>-0.67</percent_change_24h>
#       <percent_change_7d>-3.79</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>monero</id>
#    <name>Monero</name>
#    <symbol>XMR</symbol>
#    <price_usd>53.106945298</price_usd>
#    <market_cap_usd>921381028</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.29</percent_change_1h>
#       <percent_change_24h>-0.19</percent_change_24h>
#       <percent_change_7d>-2.17</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>unus-sed-leo</id>
#    <name>UNUS SED LEO</name>
#    <symbol>LEO</symbol>
#    <price_usd>0.9006000551</price_usd>
#    <market_cap_usd>900148758</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.13</percent_change_1h>
#       <percent_change_24h>-0.34</percent_change_24h>
#       <percent_change_7d>-2.06</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>chainlink</id>
#    <name>Chainlink</name>
#    <symbol>LINK</symbol>
#    <price_usd>2.2032611477</price_usd>
#    <market_cap_usd>771141402</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.03</percent_change_1h>
#       <percent_change_24h>0.9</percent_change_24h>
#       <percent_change_7d>5.68</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>cosmos</id>
#    <name>Cosmos</name>
#    <symbol>ATOM</symbol>
#    <price_usd>3.6521703362</price_usd>
#    <market_cap_usd>696426661</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.54</percent_change_1h>
#       <percent_change_24h>1.96</percent_change_24h>
#       <percent_change_7d>0.1</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>huobi-token</id>
#    <name>Huobi Token</name>
#    <symbol>HT</symbol>
#    <price_usd>2.7160191462</price_usd>
#    <market_cap_usd>655332091</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.14</percent_change_1h>
#       <percent_change_24h>0.63</percent_change_24h>
#       <percent_change_7d>-5.34</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>999-coin</id>
#    <name>999</name>
#    <symbol>999</symbol>
#    <price_usd>2.8773274714</price_usd>
#    <market_cap_usd>624671114</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.43</percent_change_1h>
#       <percent_change_24h>8.63</percent_change_24h>
#       <percent_change_7d>387.74</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>neo</id>
#    <name>NEO</name>
#    <symbol>NEO</symbol>
#    <price_usd>8.586079954</price_usd>
#    <market_cap_usd>605652043</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.28</percent_change_1h>
#       <percent_change_24h>0.07</percent_change_24h>
#       <percent_change_7d>-3.59</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>iota</id>
#    <name>IOTA</name>
#    <symbol>MIOTA</symbol>
#    <price_usd>0.1979170317</price_usd>
#    <market_cap_usd>550116383</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.43</percent_change_1h>
#       <percent_change_24h>-0.07</percent_change_24h>
#       <percent_change_7d>-2.17</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>maker</id>
#    <name>Maker</name>
#    <symbol>MKR</symbol>
#    <price_usd>490.981066732</price_usd>
#    <market_cap_usd>490981067</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.26</percent_change_1h>
#       <percent_change_24h>-2.53</percent_change_24h>
#       <percent_change_7d>-10.45</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>usd-coin</id>
#    <name>USD Coin</name>
#    <symbol>USDC</symbol>
#    <price_usd>1.0064671371</price_usd>
#    <market_cap_usd>481143899</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.24</percent_change_1h>
#       <percent_change_24h>0.08</percent_change_24h>
#       <percent_change_7d>0.29</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>mindol</id>
#    <name>MINDOL</name>
#    <symbol>MIN</symbol>
#    <price_usd>3.0935679139</price_usd>
#    <market_cap_usd>479349532</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>1.24</percent_change_1h>
#       <percent_change_24h>29.04</percent_change_24h>
#       <percent_change_7d>93.7</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dash</id>
#    <name>Dash</name>
#    <symbol>DASH</symbol>
#    <price_usd>50.046401413</price_usd>
#    <market_cap_usd>460667258</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.27</percent_change_1h>
#       <percent_change_24h>-0.44</percent_change_24h>
#       <percent_change_7d>-2.49</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ethereum-classic</id>
#    <name>Ethereum Classic</name>
#    <symbol>ETC</symbol>
#    <price_usd>3.7910297371</price_usd>
#    <market_cap_usd>438954739</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.58</percent_change_1h>
#       <percent_change_24h>0.24</percent_change_24h>
#       <percent_change_7d>-0.77</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ontology</id>
#    <name>Ontology</name>
#    <symbol>ONT</symbol>
#    <price_usd>0.5933889334</price_usd>
#    <market_cap_usd>378197131</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.32</percent_change_1h>
#       <percent_change_24h>0.37</percent_change_24h>
#       <percent_change_7d>-2.65</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>crypto-com-coin</id>
#    <name>Crypto.com Coin</name>
#    <symbol>CRO</symbol>
#    <price_usd>0.0290600533</price_usd>
#    <market_cap_usd>356231138</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.14</percent_change_1h>
#       <percent_change_24h>-0.62</percent_change_24h>
#       <percent_change_7d>9.83</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>vechain</id>
#    <name>VeChain</name>
#    <symbol>VET</symbol>
#    <price_usd>0.0061695042</price_usd>
#    <market_cap_usd>342128220</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.49</percent_change_1h>
#       <percent_change_24h>0.55</percent_change_24h>
#       <percent_change_7d>-15.44</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>nem</id>
#    <name>NEM</name>
#    <symbol>XEM</symbol>
#    <price_usd>0.0356382425</price_usd>
#    <market_cap_usd>320744182</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.12</percent_change_1h>
#       <percent_change_24h>1.66</percent_change_24h>
#       <percent_change_7d>-1.19</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>hedgetrade</id>
#    <name>HedgeTrade</name>
#    <symbol>HEDG</symbol>
#    <price_usd>1.0902457475</price_usd>
#    <market_cap_usd>314115996</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.6</percent_change_1h>
#       <percent_change_24h>0.85</percent_change_24h>
#       <percent_change_7d>50.44</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ino-coin</id>
#    <name>INO COIN</name>
#    <symbol>INO</symbol>
#    <price_usd>1.5862917214</price_usd>
#    <market_cap_usd>285537554</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.34</percent_change_1h>
#       <percent_change_24h>-0.86</percent_change_24h>
#       <percent_change_7d>-1.8</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dogecoin</id>
#    <name>Dogecoin</name>
#    <symbol>DOGE</symbol>
#    <price_usd>0.0021949344</price_usd>
#    <market_cap_usd>268713175</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.66</percent_change_1h>
#       <percent_change_24h>-0.33</percent_change_24h>
#       <percent_change_7d>-0.74</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>basic-attention-token</id>
#    <name>Basic Attention Token</name>
#    <symbol>BAT</symbol>
#    <price_usd>0.1772958682</price_usd>
#    <market_cap_usd>250156348</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.59</percent_change_1h>
#       <percent_change_24h>0.96</percent_change_24h>
#       <percent_change_7d>-5.32</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>zcash</id>
#    <name>Zcash</name>
#    <symbol>ZEC</symbol>
#    <price_usd>30.9988613439</price_usd>
#    <market_cap_usd>249329848</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.0</percent_change_1h>
#       <percent_change_24h>3.76</percent_change_24h>
#       <percent_change_7d>12.9</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>paxos-standard</id>
#    <name>Paxos Standard</name>
#    <symbol>PAX</symbol>
#    <price_usd>1.0069848173</price_usd>
#    <market_cap_usd>236070642</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.27</percent_change_1h>
#       <percent_change_24h>0.06</percent_change_24h>
#       <percent_change_7d>0.27</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>decred</id>
#    <name>Decred</name>
#    <symbol>DCR</symbol>
#    <price_usd>19.8794620892</price_usd>
#    <market_cap_usd>214436396</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.03</percent_change_1h>
#       <percent_change_24h>1.72</percent_change_24h>
#       <percent_change_7d>3.46</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>insight-chain</id>
#    <name>Insight Chain</name>
#    <symbol>INB</symbol>
#    <price_usd>0.5290688928</price_usd>
#    <market_cap_usd>185122628</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.62</percent_change_1h>
#       <percent_change_24h>0.85</percent_change_24h>
#       <percent_change_7d>-2.93</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>synthetix-network-token</id>
#    <name>Synthetix Network Token</name>
#    <symbol>SNX</symbol>
#    <price_usd>1.2217679785</price_usd>
#    <market_cap_usd>183002542</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.7</percent_change_1h>
#       <percent_change_24h>1.52</percent_change_24h>
#       <percent_change_7d>-8.2</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>prizm</id>
#    <name>PRIZM</name>
#    <symbol>PZM</symbol>
#    <price_usd>0.356492955</price_usd>
#    <market_cap_usd>177138681</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>1.22</percent_change_1h>
#       <percent_change_24h>24.78</percent_change_24h>
#       <percent_change_7d>-7.25</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>qtum</id>
#    <name>Qtum</name>
#    <symbol>QTUM</symbol>
#    <price_usd>1.7228371918</price_usd>
#    <market_cap_usd>165785460</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.61</percent_change_1h>
#       <percent_change_24h>-0.08</percent_change_24h>
#       <percent_change_7d>-1.0</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>trueusd</id>
#    <name>TrueUSD</name>
#    <symbol>TUSD</symbol>
#    <price_usd>1.0056531635</price_usd>
#    <market_cap_usd>161339661</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.24</percent_change_1h>
#       <percent_change_24h>0.19</percent_change_24h>
#       <percent_change_7d>0.56</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>0x</id>
#    <name>0x</name>
#    <symbol>ZRX</symbol>
#    <price_usd>0.2192145676</price_usd>
#    <market_cap_usd>132498100</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.19</percent_change_1h>
#       <percent_change_24h>-1.55</percent_change_24h>
#       <percent_change_7d>-8.38</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>centrality</id>
#    <name>Centrality</name>
#    <symbol>CENNZ</symbol>
#    <price_usd>0.1232706198</price_usd>
#    <market_cap_usd>131830802</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-5.14</percent_change_1h>
#       <percent_change_24h>-6.17</percent_change_24h>
#       <percent_change_7d>-8.29</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>algorand</id>
#    <name>Algorand</name>
#    <symbol>ALGO</symbol>
#    <price_usd>0.2835302689</price_usd>
#    <market_cap_usd>131319457</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.71</percent_change_1h>
#       <percent_change_24h>4.16</percent_change_24h>
#       <percent_change_7d>2.87</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ravencoin</id>
#    <name>Ravencoin</name>
#    <symbol>RVN</symbol>
#    <price_usd>0.0250003594</price_usd>
#    <market_cap_usd>126152814</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.8</percent_change_1h>
#       <percent_change_24h>4.15</percent_change_24h>
#       <percent_change_7d>-8.51</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>thorecoin</id>
#    <name>ThoreCoin</name>
#    <symbol>THR</symbol>
#    <price_usd>1373.69374936</price_usd>
#    <market_cap_usd>119080046</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.13</percent_change_1h>
#       <percent_change_24h>-0.64</percent_change_24h>
#       <percent_change_7d>-2.16</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>thorenext</id>
#    <name>ThoreNext</name>
#    <symbol>THX</symbol>
#    <price_usd>5.4419127709</price_usd>
#    <market_cap_usd>117829678</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.13</percent_change_1h>
#       <percent_change_24h>-2.77</percent_change_24h>
#       <percent_change_7d>-12.42</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>ftx-token</id>
#    <name>FTX Token</name>
#    <symbol>FTT</symbol>
#    <price_usd>1.731137979</price_usd>
#    <market_cap_usd>116389497</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.46</percent_change_1h>
#       <percent_change_24h>-2.22</percent_change_24h>
#       <percent_change_7d>-0.81</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>augur</id>
#    <name>Augur</name>
#    <symbol>REP</symbol>
#    <price_usd>10.2438614701</price_usd>
#    <market_cap_usd>112682476</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.35</percent_change_1h>
#       <percent_change_24h>2.02</percent_change_24h>
#       <percent_change_7d>0.8</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>holo</id>
#    <name>Holo</name>
#    <symbol>HOT</symbol>
#    <price_usd>0.0006724918</price_usd>
#    <market_cap_usd>108620311</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.09</percent_change_1h>
#       <percent_change_24h>-0.73</percent_change_24h>
#       <percent_change_7d>-13.17</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>karatgold-coin</id>
#    <name>Karatgold Coin</name>
#    <symbol>KBC</symbol>
#    <price_usd>0.0287666901</price_usd>
#    <market_cap_usd>107948781</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.02</percent_change_1h>
#       <percent_change_24h>2.75</percent_change_24h>
#       <percent_change_7d>6.56</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>nano</id>
#    <name>Nano</name>
#    <symbol>NANO</symbol>
#    <price_usd>0.8052084065</price_usd>
#    <market_cap_usd>107292649</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.54</percent_change_1h>
#       <percent_change_24h>0.83</percent_change_24h>
#       <percent_change_7d>-1.92</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>cryptonex</id>
#    <name>Cryptonex</name>
#    <symbol>CNX</symbol>
#    <price_usd>1.9071107375</price_usd>
#    <market_cap_usd>106199996</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.13</percent_change_1h>
#       <percent_change_24h>0.24</percent_change_24h>
#       <percent_change_7d>-0.92</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>seele</id>
#    <name>Seele</name>
#    <symbol>SEELE</symbol>
#    <price_usd>0.1507001733</price_usd>
#    <market_cap_usd>105424146</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.01</percent_change_1h>
#       <percent_change_24h>0.43</percent_change_24h>
#       <percent_change_7d>-7.08</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>educare</id>
#    <name>EDUCare</name>
#    <symbol>EKT</symbol>
#    <price_usd>0.1047063051</price_usd>
#    <market_cap_usd>104706305</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.37</percent_change_1h>
#       <percent_change_24h>4.26</percent_change_24h>
#       <percent_change_7d>33.31</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>omisego</id>
#    <name>OmiseGO</name>
#    <symbol>OMG</symbol>
#    <price_usd>0.7288185553</price_usd>
#    <market_cap_usd>102213449</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.21</percent_change_1h>
#       <percent_change_24h>1.33</percent_change_24h>
#       <percent_change_7d>-1.52</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-gold</id>
#    <name>Bitcoin Gold</name>
#    <symbol>BTG</symbol>
#    <price_usd>5.7337617763</price_usd>
#    <market_cap_usd>100420666</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.39</percent_change_1h>
#       <percent_change_24h>-0.09</percent_change_24h>
#       <percent_change_7d>-4.21</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>mixin</id>
#    <name>Mixin</name>
#    <symbol>XIN</symbol>
#    <price_usd>214.149810984</price_usd>
#    <market_cap_usd>99884550</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.17</percent_change_1h>
#       <percent_change_24h>-0.11</percent_change_24h>
#       <percent_change_7d>-1.21</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>abbc-coin</id>
#    <name>ABBC Coin</name>
#    <symbol>ABBC</symbol>
#    <price_usd>0.163587822</price_usd>
#    <market_cap_usd>91057339</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.25</percent_change_1h>
#       <percent_change_24h>-0.17</percent_change_24h>
#       <percent_change_7d>-4.08</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>zb-token</id>
#    <name>ZB Token</name>
#    <symbol>ZB</symbol>
#    <price_usd>0.1898345395</price_usd>
#    <market_cap_usd>87948218</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.13</percent_change_1h>
#       <percent_change_24h>-1.14</percent_change_24h>
#       <percent_change_7d>-2.63</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>v-systems</id>
#    <name>V Systems</name>
#    <symbol>VSYS</symbol>
#    <price_usd>0.045147271</price_usd>
#    <market_cap_usd>84531033</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.49</percent_change_1h>
#       <percent_change_24h>-5.21</percent_change_24h>
#       <percent_change_7d>-13.81</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>digibyte</id>
#    <name>DigiByte</name>
#    <symbol>DGB</symbol>
#    <price_usd>0.0064946984</price_usd>
#    <market_cap_usd>81755130</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.05</percent_change_1h>
#       <percent_change_24h>0.47</percent_change_24h>
#       <percent_change_7d>-3.56</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>lisk</id>
#    <name>Lisk</name>
#    <symbol>LSK</symbol>
#    <price_usd>0.6557666353</price_usd>
#    <market_cap_usd>79977467</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.05</percent_change_1h>
#       <percent_change_24h>0.47</percent_change_24h>
#       <percent_change_7d>-2.22</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>kucoin-shares</id>
#    <name>KuCoin Shares</name>
#    <symbol>KCS</symbol>
#    <price_usd>0.9448398807</price_usd>
#    <market_cap_usd>77820368</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.17</percent_change_1h>
#       <percent_change_24h>0.6</percent_change_24h>
#       <percent_change_7d>-2.13</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dimension-chain</id>
#    <name>Dimension Chain</name>
#    <symbol>EON</symbol>
#    <price_usd>0.3139323059</price_usd>
#    <market_cap_usd>76845468</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.19</percent_change_1h>
#       <percent_change_24h>-3.0</percent_change_24h>
#       <percent_change_7d>-11.01</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>luna</id>
#    <name>LUNA</name>
#    <symbol>LUNA</symbol>
#    <price_usd>0.259445911</price_usd>
#    <market_cap_usd>74659661</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.17</percent_change_1h>
#       <percent_change_24h>1.19</percent_change_24h>
#       <percent_change_7d>3.63</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bytom</id>
#    <name>Bytom</name>
#    <symbol>BTM</symbol>
#    <price_usd>0.0741412325</price_usd>
#    <market_cap_usd>74326532</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.85</percent_change_1h>
#       <percent_change_24h>-0.98</percent_change_24h>
#       <percent_change_7d>-6.34</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>verge</id>
#    <name>Verge</name>
#    <symbol>XVG</symbol>
#    <price_usd>0.0043536212</price_usd>
#    <market_cap_usd>70095025</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.65</percent_change_1h>
#       <percent_change_24h>6.39</percent_change_24h>
#       <percent_change_7d>10.23</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>komodo</id>
#    <name>Komodo</name>
#    <symbol>KMD</symbol>
#    <price_usd>0.5959696053</price_usd>
#    <market_cap_usd>69903338</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.04</percent_change_1h>
#       <percent_change_24h>0.98</percent_change_24h>
#       <percent_change_7d>-12.55</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitcoin-diamond</id>
#    <name>Bitcoin Diamond</name>
#    <symbol>BCD</symbol>
#    <price_usd>0.3699687868</price_usd>
#    <market_cap_usd>68996551</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.32</percent_change_1h>
#       <percent_change_24h>0.45</percent_change_24h>
#       <percent_change_7d>0.38</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>gaps</id>
#    <name>GAPS</name>
#    <symbol>GAP</symbol>
#    <price_usd>6.8621692838</price_usd>
#    <market_cap_usd>68621693</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.27</percent_change_1h>
#       <percent_change_24h>-1.78</percent_change_24h>
#       <percent_change_7d>-1.24</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>theta</id>
#    <name>THETA</name>
#    <symbol>THETA</symbol>
#    <price_usd>0.0777495517</price_usd>
#    <market_cap_usd>67681194</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.98</percent_change_1h>
#       <percent_change_24h>3.13</percent_change_24h>
#       <percent_change_7d>4.5</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>swipe</id>
#    <name>Swipe</name>
#    <symbol>SXP</symbol>
#    <price_usd>1.1034678153</price_usd>
#    <market_cap_usd>67461510</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.28</percent_change_1h>
#       <percent_change_24h>-0.44</percent_change_24h>
#       <percent_change_7d>-3.89</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>molecular-future</id>
#    <name>Molecular Future</name>
#    <symbol>MOF</symbol>
#    <price_usd>1.5293998852</price_usd>
#    <market_cap_usd>67068582</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.2</percent_change_1h>
#       <percent_change_24h>-3.88</percent_change_24h>
#       <percent_change_7d>5.25</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>1irstcoin</id>
#    <name>1irstcoin</name>
#    <symbol>FST</symbol>
#    <price_usd>1.8000142174</price_usd>
#    <market_cap_usd>66790476</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.5</percent_change_1h>
#       <percent_change_24h>-1.8</percent_change_24h>
#       <percent_change_7d>-6.5</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>beldex</id>
#    <name>Beldex</name>
#    <symbol>BDX</symbol>
#    <price_usd>0.0679781476</price_usd>
#    <market_cap_usd>66633716</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.11</percent_change_1h>
#       <percent_change_24h>-1.96</percent_change_24h>
#       <percent_change_7d>-1.41</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>crypto-com</id>
#    <name>MCO</name>
#    <symbol>MCO</symbol>
#    <price_usd>4.1590394397</price_usd>
#    <market_cap_usd>65687166</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.17</percent_change_1h>
#       <percent_change_24h>0.58</percent_change_24h>
#       <percent_change_7d>3.77</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>icon</id>
#    <name>ICON</name>
#    <symbol>ICX</symbol>
#    <price_usd>0.1268220017</price_usd>
#    <market_cap_usd>64568478</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.62</percent_change_1h>
#       <percent_change_24h>0.68</percent_change_24h>
#       <percent_change_7d>-3.83</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>iostoken</id>
#    <name>IOST</name>
#    <symbol>IOST</symbol>
#    <price_usd>0.0052519291</price_usd>
#    <market_cap_usd>63096496</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.66</percent_change_1h>
#       <percent_change_24h>0.66</percent_change_24h>
#       <percent_change_7d>-9.36</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>waves</id>
#    <name>Waves</name>
#    <symbol>WAVES</symbol>
#    <price_usd>0.626533579</price_usd>
#    <market_cap_usd>63009467</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-2.5</percent_change_1h>
#       <percent_change_24h>17.59</percent_change_24h>
#       <percent_change_7d>7.67</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>enjin-coin</id>
#    <name>Enjin Coin</name>
#    <symbol>ENJ</symbol>
#    <price_usd>0.078434974</price_usd>
#    <market_cap_usd>61568681</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.44</percent_change_1h>
#       <percent_change_24h>10.74</percent_change_24h>
#       <percent_change_7d>14.94</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bittorrent</id>
#    <name>BitTorrent</name>
#    <symbol>BTT</symbol>
#    <price_usd>0.0002888221</price_usd>
#    <market_cap_usd>61263934</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.52</percent_change_1h>
#       <percent_change_24h>-0.54</percent_change_24h>
#       <percent_change_7d>-6.21</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bytecoin-bcn</id>
#    <name>Bytecoin</name>
#    <symbol>BCN</symbol>
#    <price_usd>0.0003251664</price_usd>
#    <market_cap_usd>59852348</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.6</percent_change_1h>
#       <percent_change_24h>0.44</percent_change_24h>
#       <percent_change_7d>3.5</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>siacoin</id>
#    <name>Siacoin</name>
#    <symbol>SC</symbol>
#    <price_usd>0.0014308987</price_usd>
#    <market_cap_usd>59835958</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.94</percent_change_1h>
#       <percent_change_24h>-1.18</percent_change_24h>
#       <percent_change_7d>-6.22</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>monacoin</id>
#    <name>MonaCoin</name>
#    <symbol>MONA</symbol>
#    <price_usd>0.8831858629</price_usd>
#    <market_cap_usd>58051520</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.21</percent_change_1h>
#       <percent_change_24h>-0.41</percent_change_24h>
#       <percent_change_7d>-1.39</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>clipper-coin</id>
#    <name>Clipper Coin</name>
#    <symbol>CCC</symbol>
#    <price_usd>0.0194370197</price_usd>
#    <market_cap_usd>57208401</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-3.43</percent_change_1h>
#       <percent_change_24h>-15.33</percent_change_24h>
#       <percent_change_7d>-24.99</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>dxchain-token</id>
#    <name>DxChain Token</name>
#    <symbol>DX</symbol>
#    <price_usd>0.0011311113</price_usd>
#    <market_cap_usd>56555563</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.27</percent_change_1h>
#       <percent_change_24h>-0.95</percent_change_24h>
#       <percent_change_7d>-1.32</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>single-collateral-dai</id>
#    <name>Single Collateral DAI </name>
#    <symbol>SAI</symbol>
#    <price_usd>1.0086919833</price_usd>
#    <market_cap_usd>54796027</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.28</percent_change_1h>
#       <percent_change_24h>0.35</percent_change_24h>
#       <percent_change_7d>0.44</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>zilliqa</id>
#    <name>Zilliqa</name>
#    <symbol>ZIL</symbol>
#    <price_usd>0.0055403402</price_usd>
#    <market_cap_usd>53969837</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-1.41</percent_change_1h>
#       <percent_change_24h>0.24</percent_change_24h>
#       <percent_change_7d>-1.83</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>nexo</id>
#    <name>Nexo</name>
#    <symbol>NEXO</symbol>
#    <price_usd>0.0947521175</price_usd>
#    <market_cap_usd>53061187</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.02</percent_change_1h>
#       <percent_change_24h>-0.19</percent_change_24h>
#       <percent_change_7d>-0.39</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitshares</id>
#    <name>BitShares</name>
#    <symbol>BTS</symbol>
#    <price_usd>0.0192939647</price_usd>
#    <market_cap_usd>53044125</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.1</percent_change_1h>
#       <percent_change_24h>-0.48</percent_change_24h>
#       <percent_change_7d>-5.35</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>quant</id>
#    <name>Quant</name>
#    <symbol>QNT</symbol>
#    <price_usd>4.3228204381</price_usd>
#    <market_cap_usd>52188279</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.09</percent_change_1h>
#       <percent_change_24h>-6.35</percent_change_24h>
#       <percent_change_7d>-15.04</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>hypercash</id>
#    <name>HyperCash</name>
#    <symbol>HC</symbol>
#    <price_usd>1.1705859168</price_usd>
#    <market_cap_usd>52034250</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.66</percent_change_1h>
#       <percent_change_24h>-0.65</percent_change_24h>
#       <percent_change_7d>-4.54</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>okb</id>
#    <name>OKB</name>
#    <symbol>OKB</symbol>
#    <price_usd>2.5567640414</price_usd>
#    <market_cap_usd>51135281</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>-0.67</percent_change_1h>
#       <percent_change_24h>-2.57</percent_change_24h>
#       <percent_change_7d>-2.71</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>maidsafecoin</id>
#    <name>MaidSafeCoin</name>
#    <symbol>MAID</symbol>
#    <price_usd>0.1119359532</price_usd>
#    <market_cap_usd>50656886</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.02</percent_change_1h>
#       <percent_change_24h>0.33</percent_change_24h>
#       <percent_change_7d>-6.77</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>jewel</id>
#    <name>Jewel</name>
#    <symbol>JWL</symbol>
#    <price_usd>0.8950924606</price_usd>
#    <market_cap_usd>48970540</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.1</percent_change_1h>
#       <percent_change_24h>18.08</percent_change_24h>
#       <percent_change_7d>20.32</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>bitbook-gambling</id>
#    <name>Bitbook Gambling</name>
#    <symbol>BXK</symbol>
#    <price_usd>0.1329131373</price_usd>
#    <market_cap_usd>48963537</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>1.41</percent_change_1h>
#       <percent_change_24h>-0.17</percent_change_24h>
#       <percent_change_7d>-2.15</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>energi</id>
#    <name>Energi</name>
#    <symbol>NRG</symbol>
#    <price_usd>2.0716691192</price_usd>
#    <market_cap_usd>48585832</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>4.24</percent_change_1h>
#       <percent_change_24h>-9.23</percent_change_24h>
#       <percent_change_7d>51.44</percent_change_7d>
#    </percent_change>
# </coin>
# <coin>
#    <id>horizen</id>
#    <name>Horizen</name>
#    <symbol>ZEN</symbol>
#    <price_usd>6.0983691463</price_usd>
#    <market_cap_usd>48513060</market_cap_usd>
#    <percent_change>
#       <percent_change_1h>0.85</percent_change_1h>
#       <percent_change_24h>-1.65</percent_change_24h>
#       <percent_change_7d>18.01</percent_change_7d>
#    </percent_change>
# </coin></crypto>
